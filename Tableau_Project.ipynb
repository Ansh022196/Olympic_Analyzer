# %%
import pandas as pd 
import  numpy as np

# %%
df=pd.read_csv(r"C:\Users\anshr\Downloads\okoko.csv")

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.isnull().sum() # most major  missing value in  the Age and Height and Weight  column
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df['NOC'].value_counts()
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
#        ...
# YMD        5
# SSD        3
# UNK        2
# NBO        2
# NFL        1
# Name: NOC, Length: 230, dtype: int64

# %%
region_df=pd.read_csv(r"C:\Users\anshr\Downloads\noc_regions.csv")

# %%
region_df.shape
# Out:
# (230, 3)

# %%
df['Season']
# Out:
# 0         https://medium.com/geekculture/storytelling-wi...
# 1                                                    Summer
# 2                                                    Summer
# 3                                                    Summer
# 4                                                    Winter
#                                 ...
# 271111                                               Winter
# 271112                                               Winter
# 271113                                               Winter
# 271114                                               Winter
# 271115                                               Winter
# Name: Season, Length: 271116, dtype: object

# %%
df_season=df[df['Season']=='Summer']

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year                                             Season  \
# 0  CHN  1992 Summer  1992  https://medium.com/geekculture/storytelling-wi...
# 1  CHN  2012 Summer  2012                                             Summer
# 2  DEN  1920 Summer  1920                                             Summer
# 3  DEN  1900 Summer  1900                                             Summer
# 4  NED  1988 Winter  1988                                             Winter
#
# ...

# %%
df['Season'].value_counts()
# Out:
# Summer                                                                                                           222551
# Winter                                                                                                            48564
# https://medium.com/geekculture/storytelling-with-data-5-steps-to-transforming-your-data-analyses-8894ad1ff94b         1
# Name: Season, dtype: int64

# %%
df.shape
# Out:
# (271116, 15)

# %%
# we   want to  group by all the country wise in the noc

pd.get_dummies(df_season['Medal'])
# Out:
#         Bronze  Gold  Silver
# 1            0     0       0
# 2            0     0       0
# 3            0     1       0
# 26           0     0       0
# 27           0     0       0
# ...        ...   ...     ...
# 271106       0     0       0
# 271107       0     0       0
# 271108       0     0       0
# 271109       0     0       0
# 271110       0     0       0
#
# [222551 rows x 3 columns]

# %%
df_m=pd.concat([df_season, pd.get_dummies(df_season['Medal'])],axis=1)

# %%
df_m.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
# 27     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                                      Event Medal  Bronze  Gold  Silver
# ...

# %%
df_m.groupby(['NOC'])[['Gold','Silver','Bronze']].sum().sort_values('Gold',ascending=False).head(34)
# Out:
#        Gold  Silver  Bronze
# NOC
# USA  2472.0  1333.0  1197.0
# URS   832.0   635.0   596.0
# GBR   636.0   729.0   620.0
# GER   592.0   538.0   649.0
# ITA   518.0   474.0   454.0
# FRA   465.0   575.0   587.0
# HUN   432.0   328.0   363.0
# SWE   354.0   396.0   358.0
# AUS   342.0   452.0   510.0
# GDR   339.0   277.0   227.0
# CHN   334.0   317.0   258.0
# RUS   296.0   278.0   331.0
# NED   245.0   302.0   371.0
# JPN   230.0   287.0   333.0
# NOR   227.0   196.0   167.0
# DEN   179.0   236.0   177.0
# KOR   171.0   206.0   175.0
# CUB   164.0   129.0   116.0
# ROU   161.0   200.0   290.0
# CAN   158.0   239.0   344.0
# FRG   144.0   172.0   188.0
# FIN   132.0   125.0   217.0
# IND   131.0    19.0    40.0
# YUG   130.0   161.0    92.0
# POL   111.0   185.0   242.0
# BRA   109.0   175.0   191.0
# ESP   109.0   243.0   135.0
# SUI    99.0   178.0   139.0
# BEL    96.0   193.0   166.0
# EUN    92.0    61.0    67.0
# ARG    91.0    92.0    91.0
# NZL    90.0    55.0    82.0
# ...

# %%
df_m.shape
# Out:
# (222551, 18)

# %%
# now we have to  remove the  duplicate rows and  and  the   duplicate columns

# %%
medal=df_m.drop_duplicates(subset=['Team','NOC','Games','Year','City','Sport','Event','Medal'])

# %%
medal
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1            2                             A Lamusi   M  23.0   170.0    60.0
# 2            3                  Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271087  135556           Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 271088  135556           Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
#
# ...

# %%
medal.groupby(['NOC'])[['Gold','Silver','Bronze']].sum().sort_values('Gold',ascending=False)
# Out:
#        Gold  Silver  Bronze
# NOC
# USA  1035.0   802.0   708.0
# URS   394.0   317.0   294.0
# GBR   278.0   317.0   300.0
# GER   235.0   261.0   283.0
# FRA   234.0   256.0   287.0
# ..      ...     ...     ...
# AHO     0.0     1.0     0.0
# LBR     0.0     0.0     0.0
# LCA     0.0     0.0     0.0
# LES     0.0     0.0     0.0
# LBA     0.0     0.0     0.0
#
# [230 rows x 3 columns]

# %%
medal.to_csv('Medal')

# %%
medal.shape
# Out:
# (105636, 18)

# %%
medal['Year'].value_counts()
# Out:
# 2016    7494
# 2008    7465
# 2000    7398
# 2012    7364
# 2004    7252
# 1996    7161
# 1992    6701
# 1988    6081
# 1984    4766
# 1972    4699
# 1976    4006
# 1968    3929
# 1960    3567
# 1964    3451
# 1980    3443
# 1952    3159
# 1948    2532
# 1936    2369
# 1956    2358
# 1924    1923
# 1928    1819
# 1920    1472
# 1932    1149
# 1912    1149
# 1908     908
# 1906     687
# 1900     681
# 1904     422
# 1896     231
# Name: Year, dtype: int64

# %%
# we have   to    do the outliers analysis of the project 
medal.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        3281
# Height    19387
# Weight    19825
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     89562
# Bronze        0
# Gold          0
# Silver        0
# dtype: int64

# %%
pip install pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
medal['Age'].mean()
# Out:
# 25.3494015924967

# %%
medal['Height'].mean()
# Out:
# 174.93795870097046

# %%
medal['Weight'].mean()
# Out:
# 70.70340632319865

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
medal['Age']=medal['Age'].fillna(25)

# %%
medal['Height']=medal['Height'].fillna(175)

# %%
medal['Weight']=medal['Weight'].fillna(70)

# %%
medal.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age           0
# Height        0
# Weight        0
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     89562
# Bronze        0
# Gold          0
# Silver        0
# dtype: int64

# %%
medal.to_csv('Medal_Tally_Final')

# %%
medal['Height'].value_counts()
# Out:
# 175.0    23860
# 170.0     5247
# 180.0     4994
# 178.0     4090
# 168.0     3475
#          ...
# 212.0        1
# 218.0        1
# 216.0        1
# 133.0        1
# 128.0        1
# Name: Height, Length: 89, dtype: int64

# %%
#  now  creating the  most of the manipulation of the weigths

# %%
medal.shape
# Out:
# (105636, 19)

# %%
ok=medal['Height']/100

# %%
ok.shape
# Out:
# (105636,)

# %%
uTally=pd.concat([ok,medal],axis=1)

# %%
uTally.columns
# Out:
# Index(['Height', 'ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC',
#        'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'Bronze',
#        'Gold', 'Silver', 'Uheight'],
#       dtype='object')

# %%
# now we are calculating the bmi for the performance of the athlete 
BMI=medal['Weight']/divisor

# %%
medal['Uheight']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Uheight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
divisor=medal['Uheight']*medal['Uheight']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Uheight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
divisor
# Out:
# 1         2.8900
# 2         3.0625
# 3         3.0625
# 26        2.8224
# 27        2.8224
#            ...
# 271078    2.8224
# 271080    2.8224
# 271087    3.5721
# 271088    3.5721
# 271099    2.9241
# Name: Uheight, Length: 105636, dtype: float64

# %%
uTally.shape
# Out:
# (105636, 20)

# %%
# now  the final bmi of the  following 
BMI.shape
# Out:
# (105636,)

# %%
medal.drop('Uheight',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13064/944845767.py in <module>
# ----> 1 medal.drop('Uheight',axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
bmi_u=pd.concat([medal,BMI],axis=1)

# %%
bmi_u.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# Bronze      uint8
# Gold        uint8
# Silver      uint8
# 0         float64
# dtype: object

# %%
# now  replacing  the   columns name of  0 with the  bmi  sourcec 
bmi_u.rename(columns = {'0':'BMI'}, inplace = True)

# %%
bmi_u.columns
# Out:
# Index([    'ID',   'Name',    'Sex',    'Age', 'Height', 'Weight',   'Team',
#           'NOC',  'Games',   'Year', 'Season',   'City',  'Sport',  'Event',
#         'Medal', 'Bronze',   'Gold', 'Silver',        0],
#       dtype='object')

# %%
bmi_u
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1            2                             A Lamusi   M  23.0   170.0    60.0
# 2            3                  Gunnar Nielsen Aaby   M  24.0   175.0    70.0
# 3            4                 Edgar Lindenau Aabye   M  34.0   175.0    70.0
# 26           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0    70.0
# 27           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0    70.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271087  135556           Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 271088  135556           Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
#
# ...

# %%
pd.concat([medal['Uheight'],bmi_u],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Uheight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
bmi_u.to_csv('BMI_TALLY')

# %%
bmi_u.shape
# Out:
# (105636, 19)
